# %% [markdown]
# # Analisa Terhadap Data Dengan Pendekatan Exploratory Data Analysis

# %%
# {Memasukkan library yang akan digunakan}
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# {melakukan pembacaan pada dataset dalam format}
data = pd.read_csv('Data Survei.csv')

# %% [markdown]
# ## Analisis Data

# %%
# {Info Data}
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 9 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Data Responden                                                                502 non-null    object
#  1   Bisakah anda membedakan ms office dengan libre office?                        502 non-null    int64
#  2   Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  502 non-null    int64
#  3   Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?               502 non-null    int64
#  4   Apakah bisa menggunakan simbol matematika di microsoft excel?                 502 non-null    int64
#  5   Apakah microsoft office sangat menunjang pendidikan di kampus?                502 non-null    int64
#  6   Apakah anda sering menggunakan microsoft office?                              502 non-null    int64
#  7   Seberapa familiar anda menggunakan ms office?                                 502 non-null    int64
#  8   Bisakah anda membedakan antara file docx dan odt?                             502 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 35.4+ KB

# %%
# {Menampilkan Data Tabel}
data.head(502)
# Out:
#     Data Responden  Bisakah anda membedakan ms office dengan libre office?  \
# 0      Responden 1                                                  5
# 1      Responden 2                                                  4
# 2      Responden 3                                                  3
# 3      Responden 4                                                  4
# 4      Responden 5                                                  5
# ..             ...                                                ...
# 497  Responden 498                                                  5
# 498  Responden 499                                                  4
# 499  Responden 500                                                  4
# 500  Responden 501                                                  4
# 501  Responden 502                                                  2
#
#      Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 497                                                  5
# 498                                                  5
# 499                                                  3
# 500                                                  4
# 501                                                  4
#
#      Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# 0                                                    5
# 1                                                    5
# 2                                                    3
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 497                                                  5
# 498                                                  5
# 499                                                  5
# 500                                                  5
# 501                                                  5
#
#      Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# 0                                                    2
# 1                                                    4
# 2                                                    4
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 497                                                  5
# 498                                                  5
# 499                                                  5
# 500                                                  5
# 501                                                  5
#
#      Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# 0                                                    1
# 1                                                    5
# 2                                                    5
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 497                                                  5
# 498                                                  4
# 499                                                  4
# 500                                                  4
# 501                                                  4
#
#      Apakah anda sering menggunakan microsoft office?  \
# 0                                                   5
# 1                                                   4
# 2                                                   3
# 3                                                   5
# 4                                                   5
# ..                                                ...
# 497                                                 5
# 498                                                 4
# 499                                                 4
# 500                                                 4
# 501                                                 4
#
#      Seberapa familiar anda menggunakan ms office?  \
# 0                                                2
# 1                                                4
# 2                                                2
# 3                                                4
# 4                                                4
# ..                                             ...
# 497                                              5
# 498                                              5
# 499                                              3
# 500                                              3
# 501                                              3
#
#      Bisakah anda membedakan antara file docx dan odt?
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 497                                                  4
# 498                                                  2
# 499                                                  3
# 500                                                  2
# 501                                                  3
#
# [502 rows x 9 columns]

# %%
# {Dimensi (bentuk) Data}
data.shape
# Out:
# (502, 9)

# %%
# {Jumlah Fitur Yang Tersedia}
data.columns
# Out:
# Index(['Data Responden',
#        'Bisakah anda membedakan ms office dengan libre office?',
#        'Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?',
#        'Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?',
#        'Apakah bisa menggunakan simbol matematika di microsoft excel?',
#        'Apakah microsoft office sangat menunjang pendidikan di kampus?',
#        'Apakah anda sering menggunakan microsoft office?',
#        'Seberapa familiar anda menggunakan ms office?',
#        'Bisakah anda membedakan antara file docx dan odt?'],
#       dtype='object')

# %%
# {Statistik Data}
data.describe()
# Out:
#        Bisakah anda membedakan ms office dengan libre office?  \
# count                                          502.00000
# mean                                             3.76494
# std                                              0.96471
# min                                              1.00000
# 25%                                              3.00000
# 50%                                              4.00000
# 75%                                              4.00000
# max                                              5.00000
#
#        Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# count                                         502.000000
# mean                                            3.448207
# std                                             1.032557
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# count                                         502.000000
# mean                                            4.511952
# std                                             0.813347
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# count                                         502.000000
# mean                                            4.237052
# std                                             1.001786
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# count                                          502.00000
# mean                                             4.59761
# std                                              0.76698
# min                                              1.00000
# 25%                                              4.00000
# 50%                                              5.00000
# 75%                                              5.00000
# max                                              5.00000
#
#        Apakah anda sering menggunakan microsoft office?  \
# count                                        502.000000
# mean                                           4.418327
# std                                            0.866488
# min                                            1.000000
# 25%                                            4.000000
# 50%                                            5.000000
# 75%                                            5.000000
# max                                            5.000000
#
#        Seberapa familiar anda menggunakan ms office?  \
# count                                     502.000000
# mean                                        4.298805
# std                                         0.885883
# min                                         1.000000
# 25%                                         4.000000
# 50%                                         5.000000
# 75%                                         5.000000
# max                                         5.000000
#
#        Bisakah anda membedakan antara file docx dan odt?
# count                                         502.000000
# mean                                            3.649402
# std                                             1.055633
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# ## Correlation

# %%
# {Analisa Korelasi}
correlations = data.corr(method ="kendall")
correlations
# Out:
#                                                     Bisakah anda membedakan ms office dengan libre office?  \
# Bisakah anda membedakan ms office dengan libre ...                                           1.000000
# Mampukah anda membuat laporan (dokumen/presenta...                                           0.416094
# Menurut anda Microsoft powerpoint bisa memasukk...                                           0.092348
# Apakah bisa menggunakan simbol matematika di mi...                                           0.157648
# Apakah microsoft office sangat menunjang pendid...                                           0.053844
# Apakah anda sering menggunakan microsoft office?                                             0.131761
# Seberapa familiar anda menggunakan ms office?                                                0.141043
# Bisakah anda membedakan antara file docx dan odt?                                            0.355100
#
#                                                     Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# Bisakah anda membedakan ms office dengan libre ...                                           0.416094
# Mampukah anda membuat laporan (dokumen/presenta...                                           1.000000
# Menurut anda Microsoft powerpoint bisa memasukk...                                           0.086958
# Apakah bisa menggunakan simbol matematika di mi...                                           0.160420
# Apakah microsoft office sangat menunjang pendid...                                           0.012777
# Apakah anda sering menggunakan microsoft office?                                             0.008224
# Seberapa familiar anda menggunakan ms office?                                                0.075999
# Bisakah anda membedakan antara file docx dan odt?                                            0.287022
#
#                                                     Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# Bisakah anda membedakan ms office dengan libre ...                                           0.092348
# Mampukah anda membuat laporan (dokumen/presenta...                                           0.086958
# Menurut anda Microsoft powerpoint bisa memasukk...                                           1.000000
# Apakah bisa menggunakan simbol matematika di mi...                                           0.392320
# Apakah microsoft office sangat menunjang pendid...                                           0.372229
# Apakah anda sering menggunakan microsoft office?                                             0.344518
# Seberapa familiar anda menggunakan ms office?                                                0.341261
# Bisakah anda membedakan antara file docx dan odt?                                            0.134124
#
#                                                     Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# Bisakah anda membedakan ms office dengan libre ...                                           0.157648
# Mampukah anda membuat laporan (dokumen/presenta...                                           0.160420
# Menurut anda Microsoft powerpoint bisa memasukk...                                           0.392320
# Apakah bisa menggunakan simbol matematika di mi...                                           1.000000
# Apakah microsoft office sangat menunjang pendid...                                           0.243462
# Apakah anda sering menggunakan microsoft office?                                             0.226622
# Seberapa familiar anda menggunakan ms office?                                                0.204941
# Bisakah anda membedakan antara file docx dan odt?                                            0.154224
#
#                                                     Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# Bisakah anda membedakan ms office dengan libre ...                                           0.053844
# Mampukah anda membuat laporan (dokumen/presenta...                                           0.012777
# Menurut anda Microsoft powerpoint bisa memasukk...                                           0.372229
# Apakah bisa menggunakan simbol matematika di mi...                                           0.243462
# Apakah microsoft office sangat menunjang pendid...                                           1.000000
# Apakah anda sering menggunakan microsoft office?                                             0.512115
# Seberapa familiar anda menggunakan ms office?                                                0.389697
# Bisakah anda membedakan antara file docx dan odt?                                            0.174525
#
#                                                     Apakah anda sering menggunakan microsoft office?  \
# Bisakah anda membedakan ms office dengan libre ...                                          0.131761
# Mampukah anda membuat laporan (dokumen/presenta...                                          0.008224
# Menurut anda Microsoft powerpoint bisa memasukk...                                          0.344518
# Apakah bisa menggunakan simbol matematika di mi...                                          0.226622
# Apakah microsoft office sangat menunjang pendid...                                          0.512115
# Apakah anda sering menggunakan microsoft office?                                            1.000000
# Seberapa familiar anda menggunakan ms office?                                               0.522027
# Bisakah anda membedakan antara file docx dan odt?                                           0.233313
#
#                                                     Seberapa familiar anda menggunakan ms office?  \
# Bisakah anda membedakan ms office dengan libre ...                                       0.141043
# Mampukah anda membuat laporan (dokumen/presenta...                                       0.075999
# Menurut anda Microsoft powerpoint bisa memasukk...                                       0.341261
# Apakah bisa menggunakan simbol matematika di mi...                                       0.204941
# Apakah microsoft office sangat menunjang pendid...                                       0.389697
# Apakah anda sering menggunakan microsoft office?                                         0.522027
# Seberapa familiar anda menggunakan ms office?                                            1.000000
# Bisakah anda membedakan antara file docx dan odt?                                        0.272910
#
#                                                     Bisakah anda membedakan antara file docx dan odt?
# Bisakah anda membedakan ms office dengan libre ...                                           0.355100
# Mampukah anda membuat laporan (dokumen/presenta...                                           0.287022
# Menurut anda Microsoft powerpoint bisa memasukk...                                           0.134124
# Apakah bisa menggunakan simbol matematika di mi...                                           0.154224
# Apakah microsoft office sangat menunjang pendid...                                           0.174525
# Apakah anda sering menggunakan microsoft office?                                             0.233313
# Seberapa familiar anda menggunakan ms office?                                                0.272910
# Bisakah anda membedakan antara file docx dan odt?                                            1.000000

# %%
# {correlation map}
# higher correlations are brighter
f,ax = plt.subplots(figsize=(15,15))
sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
